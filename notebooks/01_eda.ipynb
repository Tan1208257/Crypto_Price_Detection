# %%
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_and_merge_data
from src.preprocessing import clean_data

df = clean_data(load_and_merge_data("../data/raw"))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 4 from src.data_loader import load_and_merge_data
#       5 from src.preprocessing import clean_data
#       7 df = clean_data(load_and_merge_data("../data/raw"))
#
# ModuleNotFoundError: No module named 'src'

# %%
df.describe()

# %%
sns.lineplot(
    data=df[df["symbol"]=="BTCUSDT"],
    x="timestamp",
    y="close"
)
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\jobin\Desktop\Crypto_Price_Prediction\notebooks
