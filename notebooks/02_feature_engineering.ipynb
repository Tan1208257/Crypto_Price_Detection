# %%
from src.features import create_features

df_feat = create_features(df)
df_feat.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.features import create_features
#       3 df_feat = create_features(df)
#       4 df_feat.head()
#
# ModuleNotFoundError: No module named 'src'

# %%
df_feat.to_csv("../data/processed/merged_features.csv", index=False)
